# %%
import torch
from datasets import load_dataset
from transformers import AutoTokenizer, AutoModelForCausalLM, TrainingArguments, Trainer, BitsAndBytesConfig
from peft import LoraConfig, get_peft_model, TaskType

# %%
model_name="TinyLlama/TinyLlama-1.1B-Chat-v1.0"
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type='nf4',
    bnb_4bit_compute_dtype=torch.bfloat16
)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config = bnb_config,
    device_map = 'auto',
    trust_remote_code=True
)

tokenizer = AutoTokenizer.from_pretrained(model_name,trust_remote_code=True)
# Out:
# Loading weights: 100%|██████████| 201/201 [00:18<00:00, 11.13it/s, Materializing param=model.norm.weight]

# %%
model
# Out:
# LlamaForCausalLM(
#   (model): LlamaModel(
#     (embed_tokens): Embedding(32000, 2048)
#     (layers): ModuleList(
#       (0-21): 22 x LlamaDecoderLayer(
#         (self_attn): LlamaAttention(
#           (q_proj): Linear4bit(in_features=2048, out_features=2048, bias=False)
#           (k_proj): Linear4bit(in_features=2048, out_features=256, bias=False)
#           (v_proj): Linear4bit(in_features=2048, out_features=256, bias=False)
#           (o_proj): Linear4bit(in_features=2048, out_features=2048, bias=False)
#         )
#         (mlp): LlamaMLP(
#           (gate_proj): Linear4bit(in_features=2048, out_features=5632, bias=False)
#           (up_proj): Linear4bit(in_features=2048, out_features=5632, bias=False)
#           (down_proj): Linear4bit(in_features=5632, out_features=2048, bias=False)
#           (act_fn): SiLUActivation()
#         )
#         (input_layernorm): LlamaRMSNorm((2048,), eps=1e-05)
#         (post_attention_layernorm): LlamaRMSNorm((2048,), eps=1e-05)
#       )
#     )
#     (norm): LlamaRMSNorm((2048,), eps=1e-05)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=2048, out_features=32000, bias=False)
# )

# %%
lora_config = LoraConfig(
    r=8,
    lora_alpha=16,
    target_modules=['q_proj','v_proj'],
    lora_dropout = 0.05,
    bias = 'none',
    task_type=TaskType.CAUSAL_LM
)

model = get_peft_model(model, lora_config)

# %%
data = load_dataset('openai/gsm8k', 'main', split='train[:200]')

# %%
def tokenize(batch):
    texts = [
        f"### Instruction:\n{instruction}\n### Response:\n{out}"
        for instruction, out in zip(batch['question'], batch['answer'])
    ]

    tokens = tokenizer(
        texts,
        padding = 'max_length',
        max_length = 256,
        truncation = True,
        return_tensors = 'pt'
    )

    tokens['labels'] = tokens['input_ids'].clone()
    return tokens

# %%
tokenized_data = data.map(tokenize, batched=True, remove_columns=data.column_names)
# Out:
# Map:   0%|          | 0/200 [00:00<?, ? examples/s]
# Map: 100%|██████████| 200/200 [00:00<00:00, 3120.23 examples/s]

# %%
training_args = TrainingArguments(
    output_dir='./accountant_lora_results',
    per_device_train_batch_size=1,
    gradient_accumulation_steps=4,
    learning_rate=1e-3,
    num_train_epochs=50,
    fp16=True,
    logging_steps=20,
    save_strategy='epoch',
    report_to="none",
    remove_unused_columns=False,
    label_names=['labels']
)

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_data,
    processing_class=tokenizer
)

# %%
trainer.train()
# Out:
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'pad_token_id': 2}.
# c:\Users\ianny\Desktop\Code\gauro\.venv\Lib\site-packages\torch\utils\data\dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
#     <div>
#
#       <progress value='7' max='2500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [   7/2500 06:00 < 49:54:02, 0.01 it/s, Epoch 0.12/50]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 trainer.train()
#
# File c:\Users\ianny\Desktop\Code\gauro\.venv\Lib\site-packages\transformers\trainer.py:2170, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2168         hf_hub_utils.enable_progress_bars()
#    2169 else:
# -> 2170     return inner_training_loop(
#    2171         args=args,
#    2172         resume_from_checkpoint=resume_from_checkpoint,
#    2173         trial=trial,
#    2174         ignore_keys_for_eval=ignore_keys_for_eval,
#    2175     )
#
# File c:\Users\ianny\Desktop\Code\gauro\.venv\Lib\site-packages\transformers\trainer.py:2537, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2530 context = (
#    2531     functools.partial(self.accelerator.no_sync, model=model)
#    2532     if i != len(batch_samples) - 1
#    2533     and self.accelerator.distributed_type != DistributedType.DEEPSPEED
#    2534     else contextlib.nullcontext
#    2535 )
#    2536 with context():
# -> 2537     tr_loss_step = self.training_step(model, inputs, num_items_in_batch)
#    2539 if (
#    2540     args.logging_nan_inf_filter
#    2541     and not is_torch_xla_available()
#    2542     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    2543 ):
#    2544     # if loss is nan or inf simply add the average of previous logged losses
#    2545     tr_loss = tr_loss + tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#
# File c:\Users\ianny\Desktop\Code\gauro\.venv\Lib\site-packages\transformers\trainer.py:3838, in Trainer.training_step(***failed resolving arguments***)
#    3835 if self.accelerator.distributed_type == DistributedType.DEEPSPEED:
#    3836     kwargs["scale_wrt_gas"] = False
# -> 3838 self.accelerator.backward(loss, **kwargs)
#    3840 return loss.detach()
#
# File c:\Users\ianny\Desktop\Code\gauro\.venv\Lib\site-packages\accelerate\accelerator.py:2852, in Accelerator.backward(self, loss, **kwargs)
#    2850     self.lomo_backward(loss, learning_rate)
#    2851 else:
# -> 2852     loss.backward(**kwargs)
#
# File c:\Users\ianny\Desktop\Code\gauro\.venv\Lib\site-packages\torch\_tensor.py:630, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     620 if has_torch_function_unary(self):
#     621     return handle_torch_function(
#     622         Tensor.backward,
#     623         (self,),
#    (...)    628         inputs=inputs,
#     629     )
# --> 630 torch.autograd.backward(
#     631     self, gradient, retain_graph, create_graph, inputs=inputs
#     632 )
#
# File c:\Users\ianny\Desktop\Code\gauro\.venv\Lib\site-packages\torch\autograd\__init__.py:364, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     359     retain_graph = create_graph
#     361 # The reason we repeat the same comment below is that
#     362 # some Python versions print out the first line of a multi-line function
#     363 # calls in the traceback and some print out the last line
# --> 364 _engine_run_backward(
#     365     tensors,
#     366     grad_tensors_,
#     367     retain_graph,
#     368     create_graph,
#     369     inputs_tuple,
#     370     allow_unreachable=True,
#     371     accumulate_grad=True,
#     372 )
#
# File c:\Users\ianny\Desktop\Code\gauro\.venv\Lib\site-packages\torch\autograd\graph.py:865, in _engine_run_backward(t_outputs, *args, **kwargs)
#     863     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     864 try:
# --> 865     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     866         t_outputs, *args, **kwargs
#     867     )  # Calls into the C++ engine to run the backward pass
#     868 finally:
#     869     if attach_logging_hooks:
#
# File c:\Users\ianny\Desktop\Code\gauro\.venv\Lib\site-packages\torch\autograd\function.py:302, in BackwardCFunction.apply(self, *args)
#     297 class BackwardCFunction(_C._FunctionBase, FunctionCtx, _HookMixin):
#     298     r"""
#     299     This class is used for internal autograd work. Do not use.
#     300     """
# --> 302     def apply(self, *args):
#     303         r"""
#     304         Apply method used when executing this Node during the backward
#     305         """
#     306         # _forward_cls is defined by derived class
#     307         # The user should define either backward or vjp but never both.
#
# KeyboardInterrupt:

# %%
model.save_pretrained('./accountant_lora_model')
tokenizer.save_pretrained('./accountant_lora_model')
